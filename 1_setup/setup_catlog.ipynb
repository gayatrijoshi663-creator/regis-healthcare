# %%
# %sql
CREATE CATALOG IF NOT EXISTS regis_healthcare ;
USE CATALOG regis_healthcare ;

# %%
# %sql
CREATE Schema IF NOT EXISTS regis_healthcare.bronze ;
CREATE Schema IF NOT EXISTS regis_healthcare.silver ;
CREATE Schema IF NOT EXISTS regis_healthcare.gold ;
